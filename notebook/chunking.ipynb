# %%
import json
with open(r"D:\Programing\Github\Persian-Medical-RAG-Chatbot\data\processed/chunks.jsonl", encoding="utf-8") as f:
    records = [json.loads(line) for line in f]

split_records = [r for r in records if r["was_split"]]
print("Total chunks:", len(records))
print("Chunks from split records:", len(split_records))
print("Max chunk_index seen:", max(r["chunk_index"] for r in records))
# Out:
# Total chunks: 4805
# Chunks from split records: 152
# Max chunk_index seen: 4
